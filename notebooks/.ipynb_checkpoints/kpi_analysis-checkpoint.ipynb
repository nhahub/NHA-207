# %%
# import sys, os
# sys.path.append(os.path.abspath('../scripts'))
import pandas as pd
# from kpi_functions import *
employeeDF = pd.read_csv('../data/clean/employee_clean.csv')

bigDF = pd.read_csv('../data/clean/bigTable.csv')

# %%
# gender_distribution(employeeDF)
def gender_distribution(df, show_output=True):
    gender_dist = df['gender'].value_counts(normalize=True) * 100
    gender_dist = gender_dist.round(2)
    if show_output:
        print("\n Gender Distribution (%):")
        for key, val in gender_dist.items():
            print(f'{key} : {val} %')
    return gender_dist

# %%
gender_distribution(employeeDF, True)
# Out:
#  Gender Distribution (%):
# Female : 45.92 %
# Male : 44.29 %
# Non-Binary : 8.44 %
# Prefer Not To Say : 1.36 %
# gender
# Female               45.92
# Male                 44.29
# Non-Binary            8.44
# Prefer Not To Say     1.36
# Name: proportion, dtype: float64

# %%
# Age Distibution
def age_statistics(df, show_output=True):
    """
    Calculates mean, median, and range of employee ages.

    Args:
        df (pd.DataFrame): Employee dataframe.
        show_output (bool): Whether to print the summary.

    Returns:
        dict: Contains 'mean', 'median', and 'range' of Age.
    """
    stats = {
        'mean': df['age'].mean(),
        'median': df['age'].median(),
        'range': df['age'].max() - df['age'].min()
    }
    if show_output:
        print("\n📊 Age Statistics:")
        print(f"Average Age: {stats['mean']:.2f}")
        print(f"Median Age: {stats['median']}")
        print(f"Age Range: {stats['range']}")
    return stats

# %%
age_statistics(employeeDF, True)
print(employeeDF.columns)
print(bigDF.columns)
# Out:
# 📊 Age Statistics:
# Average Age: 28.99
# Median Age: 26.0
# Age Range: 33
# Index(['employeeid', 'firstname', 'lastname', 'gender', 'age',
#        'businesstravel', 'department', 'distancefromhome_km', 'state',
#        'ethnicity', 'education', 'educationfield', 'jobrole', 'maritalstatus',
#        'salary', 'stockoptionlevel', 'overtime', 'hiredate', 'attrition',
#        'yearsatcompany', 'yearsinmostrecentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager'],
#       dtype='object')
# Index(['employeeid', 'firstname', 'lastname', 'gender', 'age',
#        'businesstravel', 'department', 'distancefromhome_km', 'state',
#        'ethnicity', 'education', 'educationfield', 'jobrole', 'maritalstatus',
#        'salary', 'stockoptionlevel', 'overtime', 'hiredate', 'attrition',
#        'yearsatcompany', 'yearsinmostrecentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'educationlevelid', 'educationlevel',
#        'performanceid', 'reviewdate', 'environmentsatisfaction',
#        'jobsatisfaction', 'relationshipsatisfaction',
#        'trainingopportunitieswithinyear', 'trainingopportunitiestaken',
#        'worklifebalance', 'selfrating', 'managerrating', 'satisfactionid',
#        'satisfactionlevel', 'satisfactionid_job', 'satisfactionlevel_job',
#        'satisfactionid_rel', 'satisfactionlevel_rel', 'ratingid',
#        'ratinglevel', 'ratingid_manager', 'ratinglevel_manager'],
#       dtype='object')

# %%
# EDUCATION LEVEL DISTRIBUTION
def education_distribution(df, show_output=True):
    """
    Calculates the number of employees per education level.
    Requires the merged dataset (bigDF) with EducationLevel column.

    Args:
        df (pd.DataFrame): Merged dataset containing 'EducationLevel'.
        show_output (bool): Whether to print the summary.

    Returns:
        pd.Series: Employee counts by EducationLevel.
    """
    edu_dist = df['educationlevel'].value_counts()
    if show_output:
        print("\n🎓 Education Level Distribution:")
        print(edu_dist)
    return edu_dist

# %%
education_distribution(bigDF, True)
# Out:
# 🎓 Education Level Distribution:
# educationlevel
# Bachelors                   2706
# Masters                     1738
# High School                 1380
# No Formal Qualifications     857
# Doctorate                    218
# Name: count, dtype: int64
# educationlevel
# Bachelors                   2706
# Masters                     1738
# High School                 1380
# No Formal Qualifications     857
# Doctorate                    218
# Name: count, dtype: int64

# %%
# DEPARTMENT DISTRIBUTION
# -------------------------------------------------------------
def department_distribution(df, show_output=True):
    """
    Counts number of employees in each department.

    Args:
        df (pd.DataFrame): Employee dataframe.
        show_output (bool): Whether to print the summary.

    Returns:
        pd.Series: Employee counts by Department.
    """
    dept_dist = df['department'].value_counts()
    if show_output:
        print("\n🏢 Department Distribution:")
        print(dept_dist)
    return dept_dist

# %%
department_distribution(employeeDF, True)
# Out:
# 🏢 Department Distribution:
# department
# Technology         961
# Sales              446
# Human Resources     63
# Name: count, dtype: int64
# department
# Technology         961
# Sales              446
# Human Resources     63
# Name: count, dtype: int64

# %%
# TENURE STATISTICS
# -------------------------------------------------------------
def tenure_statistics(df, show_output=True):
    """
    Calculates mean, median, and range of YearsAtCompany.

    Args:
        df (pd.DataFrame): Employee dataframe.
        show_output (bool): Whether to print the summary.

    Returns:
        dict: Contains 'mean', 'median', and 'range' for tenure.
    """
    stats = {
        'mean': df['yearsatcompany'].mean(),
        'median': df['yearsatcompany'].median(),
        'range': df['yearsatcompany'].max() - df['YearsAtCompany'].min()
    }
    if show_output:
        print("\n⏱️ Tenure Statistics:")
        print(f"Average Years at Company: {stats['mean']:.2f}")
        print(f"Median Years: {stats['median']}")
        print(f"Range (Max - Min): {stats['range']}")
    return stats

# %%
tenure_statistics(employeeDF, True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\Final Project Data Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearsAtCompany'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 tenure_statistics(employeeDF, True)
#
# Cell In[74], line 17, in tenure_statistics(df, show_output)
#       3 def tenure_statistics(df, show_output=True):
#       4     """
#       5     Calculates mean, median, and range of YearsAtCompany.
#       6
#    (...)     12         dict: Contains 'mean', 'median', and 'range' for tenure.
#      13     """
#      14     stats = {
#      15         'mean': df['yearsatcompany'].mean(),
#      16         'median': df['yearsatcompany'].median(),
# ---> 17         'range': df['yearsatcompany'].max() - df['YearsAtCompany'].min()
#      18     }
#      19     if show_output:
#      20         print("\n⏱️ Tenure Statistics:")
#
# File ~\Desktop\Final Project Data Analysis\.venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\Desktop\Final Project Data Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'YearsAtCompany'
